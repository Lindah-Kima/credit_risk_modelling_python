# %% [markdown]
# Logistic regression - is recovery rate 0 or greater than 0
#
# Linear regression - by how much is the recovery rate greater than 0
#
# For credit conversion factors - multiple linear regression model

# %% [markdown]
# ### LGD modle

# %% [markdown]
# #### Splitting data

# %%
from sklearn.model_selection import train_test_split

# %%
# LGD model stage 1 datasets: recovery rate 0 or greater than 0.

lgd_inputs_stage_1_train, 
lgd_inputs_stage_1_test, 
lgd_targets_stage_1_train, 
lgd_targets_stage_1_test = train_test_split(loan_data_defaults.drop(['good_bad', 'recovery_rate','recovery_rate_0_1', 'CCF'], axis = 1), 
                                            loan_data_defaults['recovery_rate_0_1'], test_size = 0.2, random_state = 42)
# Takes a set of inputs and a set of targets as arguments. Splits the inputs and the targets into four dataframes:
# Inputs - Train, Inputs - Test, Targets - Train, Targets - Test.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 # LGD model stage 1 datasets: recovery rate 0 or greater than 0.
# ----> 3 lgd_inputs_stage_1_train,
#       4 lgd_inputs_stage_1_test,
#       5 lgd_targets_stage_1_train,
#
# NameError: name 'lgd_inputs_stage_1_train' is not defined
